# %%
from collections import defaultdict
from itertools import chain

import pandas as pd
import re

ARQUIVO_MODELO_RAW = "produtos-drop-gb-mto-list-03052025163523.xls"

PADRAO_ANO = r"\sAno:\s*(\d+)\s*até:\s*(\d+)$"


def extrair_ano_inicial_ano_final(modelo_raw):
    match = re.search(PADRAO_ANO, modelo_raw)
    if match:
        return match.groups()
    return None, None


def is_valid(a):
    try:
        a.strip()
        return True
    except AttributeError:
        return False


def ler_descricoes_raw():
    df = pd.read_excel(ARQUIVO_MODELO_RAW, usecols=["Aplicacao"])
    aplicacoes = chain.from_iterable(a.split("\n") for a in df.Aplicacao if is_valid(a))
    return set(a.strip() for a in aplicacoes if a.strip())


def to_dict(df):
    return {r["value_name"].strip(): int(r["value_id"]) for _, r in df.iterrows()}


def nome_contem_string(nome_raw, string_):
    return bool(re.search(f"\\W*{string_}\\W+", nome_raw, re.I))


marcas = to_dict(pd.read_excel('marcas.xlsx'))
modelos = to_dict(pd.read_excel('modelos.xlsx'))
#Mercedes-Benz
marcas["CITROEN"] = marcas["Citroën"]
marcas["Mercedes Benz"] = marcas["Mercedes-Benz"]
descricoes_raw = ler_descricoes_raw()

# %%
len(descricoes_raw)
# Out:
# 118161

# %%
with open("descricoes_raw.txt", "w", encoding="utf8") as f:
    for descricao in sorted(descricoes_raw):
        f.write(f"{descricao}\n")

# %%
marcas
# Out:
# {'AMC': 2253232,
#  'ARO': 2220868,
#  'Acura': 60244,
#  'Agrale': 380854,
#  'Aleko': 2817419,
#  'Alfa Romeo': 67695,
#  'Am Gen': 2130482,
#  'Anchi': 2103722,
#  'Asaki': 3184339,
#  'Asia': 378440,
#  'Aston Martin': 69160,
#  'Audi': 40661,
#  'BAIC': 2088960,
#  'BAW': 411107,
#  'BJC': 3184340,
#  'BLAC': 3184341,
#  'BMW': 66352,
#  'BRM': 1119486,
#  'BYD': 2103733,
#  'Beiney': 3184338,
#  'Bentley': 68451,
#  'Bestune': 11058681,
#  'Bognor': 3184343,
#  'Brilliance': 2103723,
#  'Buggy': 1119487,
#  'Bugre': 1119488,
#  'Buick': 67288,
#  'CBT Jipe': 2130483,
#  'Cadillac': 24050,
#  'Caterham': 3640508,
#  'Chana': 389166,
#  'Changan': 389167,
#  'Changfeng': 8782166,
#  'Changhe': 2103721,
#  'Chery': 389168,
#  'Chevrolet': 58955,
#  'Chrysler': 66395,
#  'Citroën': 389169,
#  'Cross Lander': 1119489,
#  'D.S.': 28040447,
#  'DFAC': 8782169,
#  'DFM': 71467,
#  'DFM/DFSK': 5826391,
#  'DFSK': 2103629,
#  'Dacia': 2220869,
#  'Daewoo': 4208,
#  'Daihatsu': 10075,
#  'Dodge': 66708,
#  'Dongfeng': 1253268,
#  'Effa': 378442,
#  'Engesa': 389170,
#  'Envemo': 1119490,
#  'FAW': 70603,
#  'FSO': 2400402,
#  'Ferrari': 23937,
#  'Fiat': 67781,
#  'Fibravan': 1119491,
#  'Fisker': 73265,
#  'Ford': 66432,
#  'Forland': 3184342,
#  'Foton': 396748,
#  'Fuqi': 3184344,
#  'Fuqui': 2400403,
#  'Fuso': 8266712,
#  'Fyber': 1119492,
#  'GAC Trumpchi': 3184351,
#  'GWM': 17820030,
#  'Gaz': 8782168,
#  'Geely': 389171,
#  'Glow': 2617718,
#  'Gonow': 2103724,
#  'Gurgel': 399558,
#  'Hafei': 378443,
#  'Hafei Towner': 389172,
#  'Haima': 2103726,
#  'Higer': 2400401,
#  'Honda': 60559,
#  'Huanghai': 8782167,
#  'Huayang': 2400404,
#  'Hummer': 60407,
#  'Hyundai': 1089,
#  'Infiniti': 14419,
#  'International': 19595,
#  'Isuka': 3564001,
#  'Isuzu': 60648,
#  'Iveco': 396749,
#  'JAC': 2839844,
#  'JMC': 2220871,
#  'JPX': 2130480,
#  'Jaguar': 23629,
#  'Jeep': 60395,
#  'Jetour': 8569062,
#  'Jinbei': 389174,
#  'Kama': 2103628,
#  'Karry': 8569063,
#  'Kenbo': 2103730,
#  'Kia': 374002,
#  'Lada': 378444,
#  'Lamborghini': 68762,
#  'Lancia': 70621,
#  'Land Rover': 66655,
#  'Lexus': 71552,
#  'Lifan': 380878,
#  'Lincoln': 66671,
#  'Lobini': 389175,
#  'Lotus': 19640,
#  'MG': 64522,
#  'Mack': 503296,
#  'Mahindra': 389176,
#  'Maple': 2848163,
#  'Maserati': 64049,
#  'Mastretta': 64021,
#  'Matra': 2130481,
#  'Maxus': 7358651,
#  'Maybach': 64540,
#  'Mazda': 66811,
#  'McLaren': 63904,
#  'Mega': 24852,
#  'Mercedes-Benz': 75966,
#  'Mercury': 33474,
#  'Metro': 3184345,
#  'Mini': 65127,
#  'Mitsubishi': 1138,
#  'Miura': 227543,
#  'Monde': 3184346,
#  'Morgan': 64039,
#  'Morris': 396998,
#  'Mudan': 8782170,
#  'NSU': 3184336,
#  'Nanjing': 2400400,
#  'Nash': 2707734,
#  'Neckar': 3184349,
#  'Nissan': 60505,
#  'Noble': 2400407,
#  'Oldsmobile': 2400405,
#  'Oltcit': 3184337,
#  'Opel': 61705,
#  'Orient': 26558,
#  'Peugeot': 60279,
#  'Piaggio': 505277,
#  'Plymouth': 396999,
#  'Pontiac': 60495,
#  'Porsche': 56870,
#  'Proton': 2220870,
#  'RAM': 2710997,
#  'Rely': 389178,
#  'Renault': 9909,
#  'Rocar': 3184348,
#  'Rolls-Royce': 61825,
#  'Rover': 60589,
#  'SAAB': 61745,
#  'SMA': 3663698,
#  'Samsung': 206,
#  'Sanfeng': 3184350,
#  'Santa Matilde': 378446,
#  'Sanxing': 2400406,
#  'Saturn': 60524,
#  'Scion': 3007068,
#  'Seat': 60268,
#  'Sero Electric': 8247208,
#  'Shelby': 63740,
#  'Shineray': 380886,
#  'Shuanghuan': 8266705,
#  'Skoda': 2317930,
#  'Smart': 38765,
#  'Soueast': 5826390,
#  'Soyat': 8782171,
#  'SsangYong': 378447,
#  'Subaru': 60285,
#  'Suzuki': 43943,
#  'TAC': 7096049,
#  'TATA': 1218189,
#  'Tavria': 3184347,
#  'Tesla': 2130484,
#  'Toyota': 60297,
#  'Trike': 12067228,
#  'Troller': 389179,
#  'UFO': 2474205,
#  'Victory Auto': 2103731,
#  'Volga': 8782175,
#  'Volkswagen': 60249,
#  'Volt Motors': 8295766,
#  'Volvo': 60658,
#  'Wake': 1119495,
#  'Walk': 143291,
#  'Wuling': 2103734,
#  'Xinkai': 2347833,
#  'YUGO': 8782173,
#  'Yasuki': 2236981,
#  'Zahav': 8782174,
#  'Zanella': 108389,
#  'Zhongxing': 5826392,
#  'Zna': 2103729,
#  'Zongshen': 2370633,
#  'Zotye': 2103728,
#  'ZxAuto': 2103725}

# %%
modelos
# Out:
# {'1': 34546,
#  '10': 9267,
#  '100': 8943,
#  '1000': 8272,
#  '1007': 922967,
#  '1020': 59332,
#  '1022': 12564,
#  '1025': 11530,
#  '105': 11194,
#  '106': 41716,
#  '1061': 2498194,
#  '107': 22472,
#  '108': 43829,
#  '11': 45327,
#  '110': 10320,
#  '1102': 2468938,
#  '111': 13009,
#  '112': 18220,
#  '115': 19297,
#  '121': 110493,
#  '124': 568935,
#  '125': 10042,
#  '126': 50452,
#  '127': 104205,
#  '1275 Mini': 3487198,
#  '128': 10304,
#  '12C Coupe': 503636,
#  '12C Spider': 84830,
#  '1310': 12975,
#  '132': 2318078,
#  '137': 59967,
#  '137 Sport': 2318116,
#  '1410': 9963,
#  '145': 13905,
#  '146': 1252944,
#  '147': 58843,
#  '147 Spazio': 2130516,
#  '1500': 8037,
#  '155': 77695,
#  '156': 68769,
#  '156 Sportwagon': 1252945,
#  '159': 67714,
#  '1600': 10697,
#  '164': 11976,
#  '166': 74513,
#  '170': 47235,
#  '180-D': 389383,
#  '19': 54922,
#  '190': 130,
#  '1970': 51098,
#  '2': 59481,
#  '200': 9064,
#  '200 SX': 1252954,
#  '2002': 516492,
#  '2008': 65895,
#  '200S': 5958862,
#  '205': 9894,
#  '205 Minitruck': 3487199,
#  '206': 53433,
#  '206 CC': 389384,
#  '206 SW': 389385,
#  '207': 9215,
#  '207 CC': 2347948,
#  '207 Compact': 1252904,
#  '207 Passion': 389386,
#  '207 SW': 389387,
#  '208': 9301,
#  '21': 17764,
#  '2104': 2109406,
#  '2105': 14357,
#  '21053': 5076707,
#  '2106': 2318090,
#  '2107': 2318091,
#  '2121': 503316,
#  '214': 2109383,
#  '2141': 3028724,
#  '216': 34825,
#  '218': 2220978,
#  '220': 10494,
#  '222': 19509,
#  '228': 468255,
#  '230': 11015,
#  '2300': 3151,
#  '2335': 14277,
#  '240': 13390,
#  '240 SX': 503692,
#  '240SX': 65571,
#  '243': 2251656,
#  '244': 1165458,
#  '245': 9980,
#  '246': 1182124,
#  '25': 18844,
#  '250': 10630,
#  '2500': 7276,
#  '260': 10051,
#  '264': 2220935,
#  '275': 40749,
#  '280': 12254,
#  '280 SE': 68376,
#  '2CV': 7407929,
#  '3': 49506,
#  '3 SPEED': 5958868,
#  '3 Wheeler': 3572359,
#  '3-Eleven': 503655,
#  '300': 566,
#  '300 D': 120048,
#  '300 M': 68473,
#  '300 SE': 84831,
#  '300 SRT': 503682,
#  '300 ZX': 503693,
#  '3000': 9159,
#  '3000 GT': 84832,
#  '3008': 61646,
#  '300C': 10127,
#  '300M': 74769,
#  '300S': 14969,
#  '300ZX': 62319,
#  '301': 10279,
#  '3041': 2400687,
#  '305': 10070,
#  '306': 51558,
#  '307': 36046,
#  '307 CC': 389388,
#  '307 SW': 85033,
#  '307 Sedan': 389389,
#  '308': 5246,
#  '308 CC': 2347949,
#  '309': 766,
#  '320': 102,
#  '3200 GT': 67627,
#  '323': 13278,
#  '324': 42125,
#  '325': 10490,
#  '33': 15982,
#  '330': 10498,
#  '3350Z Coupé': 1007109,
#  '348 GTS': 5958938,
#  '350': 10517,
#  '3500': 8412,
#  '350Z': 7352303,
#  '355': 48751,
#  '360': 9809,
#  '370Z': 62298,
#  '3CV': 1252935,
#  '4000': 10394,
#  '4007': 14901,
#  '4008': 10481,
#  '404': 16236,
#  '404 Pick-Up': 2109368,
#  '405': 4669133,
#  '406': 62274,
#  '407': 42378,
#  '407 SW': 389390,
#  '408': 7167,
#  '414': 2220969,
#  '416': 93415,
#  '420': 9475,
#  '4200': 3186,
#  '430': 4106,
#  '430 Scuderia': 2220958,
#  '430 Spider': 2220950,
#  '430 ii': 468261,
#  '43168': 5958830,
#  '440': 12639,
#  '45': 10336,
#  '450': 9243,
#  '450 SL': 71328,
#  '450 SLC': 69582,
#  '454': 503673,
#  '456': 68300,
#  '458': 71672,
#  '458 Italia': 7325480,
#  '458 Speciale': 7248551,
#  '458 Spider': 7248585,
#  '460': 25056,
#  '485': 235785,
#  '488': 110580,
#  '488 GTB': 1119436,
#  '4C': 1119435,
#  '4Runner': 60924,
#  '500': 9069,
#  '500 SEL': 70254,
#  '5008': 9857,
#  '500C': 10308,
#  '500L': 519080,
#  '500X': 1165297,
#  '5022': 42790,
#  '5025': 2662819,
#  '504': 14685,
#  '504 Pick Up': 389391,
#  '504 Pick-Up': 2109367,
#  '505': 47233,
#  '508': 47303,
#  '515': 51150,
#  '520': 56013,
#  '520 L': 2347930,
#  '530': 100746,
#  '540C': 503640,
#  '550': 9787,
#  '560 SEC': 503707,
#  '57': 18303,
#  '57 S': 503635,
#  '57 Zeppelin': 84823,
#  '570 S Coupé': 1046561,
#  '570 S Spyder': 1046560,
#  '570GT': 503639,
#  '570S': 20663,
#  '575': 39774,
#  '599': 66691,
#  '599 GTB Fiorano': 2486977,
#  '6': 59833,
#  '600': 9883,
#  '604': 46445,
#  '605': 10679,
#  '607': 9192,
#  '612': 3228,
#  '612 Scaglietti': 2486976,
#  '618': 5436,
#  '62': 10341,
#  '62 S': 84824,
#  '62 Zeppelin': 84822,
#  '620': 53353,
#  '623': 2220973,
#  '626': 389382,
#  '630': 59747,
#  '6363': 2662820,
#  '650': 10242,
#  '650S Coupe': 84829,
#  '650S Spider': 84828,
#  '6608': 3228227,
#  '675LT Coupe': 503637,
#  '675LT Spider': 503638,
#  '7': 27251,
#  '70': 14260,
#  '700': 5388,
#  '710': 8887,
#  '718': 1119451,
#  '718 boxster': 462950,
#  '718 cayman': 463752,
#  '720': 56266,
#  '720 S Coupé': 1046559,
#  '740': 9888,
#  '75': 8167,
#  '75 Milano': 2220945,
#  '750': 10727,
#  '760': 6310,
#  '80': 19022,
#  '80 Limousine': 2220941,
#  '800': 5442,
#  '806': 200959,
#  '807': 145089,
#  '820': 6488,
#  '827': 20021,
#  '85': 25387,
#  '850': 4134,
#  '850 Mini': 3487200,
#  '86': 1252923,
#  '8C': 2486956,
#  '9-3': 61910,
#  '9-4X': 64047,
#  '9-5': 61747,
#  '90': 10470,
#  '900': 9113,
#  '9000': 2522,
#  '911': 60259,
#  '911 Let': 2251644,
#  '911 Targa': 1007086,
#  '918': 63929,
#  '918 Spyder': 7215652,
#  '924': 13358,
#  '928': 13680,
#  '929': 171180,
#  '930': 10259,
#  '940': 50877,
#  '944': 9171,
#  '945': 18230,
#  '960': 11227,
#  '968': 13441,
#  'A 516': 2318057,
#  'A class': 2347931,
#  'A1': 7698,
#  'A1 Sportback': 3228233,
#  'A100': 6828,
#  'A113': 2400668,
#  'A137': 5958945,
#  'A138': 4612290,
#  'A20': 8073,
#  'A21': 465456,
#  'A3': 59350,
#  'A3 Cabriolet': 71491,
#  'A3 Sedan': 3228242,
#  'A3 Sedán': 3304618,
#  'A3 Sportback': 2726240,
#  'A4': 66459,
#  'A4 Allroad': 2220936,
#  'A4 Avant': 389392,
#  'A5': 121559,
#  'A5 Cabriolet': 71484,
#  'A6': 37931,
#  'A6 Avant': 389393,
#  'A7': 175584,
#  'A8': 67351,
#  'A9': 84781,
#  'ACTIVEHYBRID': 5958888,
#  'Acuario': 3057268,
#  'AD VAN': 2347920,
#  'ADVANCER': 5958877,
#  'Adventure': 108345,
#  'Alaskan': 5958853,
#  'ALLEGRO': 5958865,
#  'ALLURE': 5958887,
#  'AM': 2318052,
#  'APV': 2318129,
#  'ASX': 74118,
#  'ATS': 72500,
#  'ATS Coupé': 1119434,
#  'AUTANA': 5958882,
#  'AVEO EMOTION': 5958844,
#  'AX': 47582,
#  'AX7': 2318069,
#  'Acadia': 60582,
#  'Acapulco': 68780,
#  'Accent': 63922,
#  'Accent Hatchback': 2318128,
#  'Accord': 61710,
#  'Action Sports': 2109324,
#  'Actyon': 84853,
#  'Actyon Sports': 2318124,
#  'Acura': 503716,
#  'Ad Wagon': 1252955,
#  'Admiral': 9086,
#  'Aerio': 64552,
#  'Aero': 40020,
#  'Aerostar': 70040,
#  'Afalina': 1252977,
#  'Agila': 2486980,
#  'Agile': 84465,
#  'Aircross': 389394,
#  'Airtrek': 389395,
#  'Albea': 71720,
#  'Alhambra': 60597,
#  'Alliance': 64101,
#  'Allroad': 73123,
#  'Almera': 62342,
#  'Alsvin': 3572351,
#  'Altea': 60830,
#  'Alter': 2109299,
#  'Altezza': 2347938,
#  'Altima': 60704,
#  'Alto': 1252963,
#  'Amarok': 63686,
#  'Amazon': 2109349,
#  'AMG GT S': 6961840,
#  'Amigo': 84814,
#  'Antara': 84836,
#  'Aojun': 2109407,
#  'Apache': 67343,
#  'Apollo': 42959,
#  'Applause': 1252968,
#  'Aprio': 60506,
#  'Argenta': 85744,
#  'Argo': 1119416,
#  'Arizona': 130919,
#  'Armada': 61188,
#  'Arnage': 75227,
#  'Arrizo': 2400670,
#  'Arrizo 5': 2820709,
#  'Arrizo 6': 11688223,
#  'Artis': 522234,
#  'Aspen': 31815,
#  'Aspire': 389396,
#  'Astra': 15180,
#  'Astra Sedan': 389397,
#  'Astra wagon': 2130525,
#  'Astro': 67460,
#  'Astro Safari': 85055,
#  'Astro Van': 503672,
#  'AstroVan': 84802,
#  'Ateca': 1119452,
#  'Atlantic': 62785,
#  'Atos': 67536,
#  'Attitude': 56467,
#  'Auman': 503336,
#  'Aumark': 503337,
#  'Aura': 31819,
#  'Auris': 2318092,
#  'Austin': 2318093,
#  'Avalanche': 70008,
#  'Avalon': 63927,
#  'Avante': 2318094,
#  'Avanza': 60701,
#  'Avella': 1252974,
#  'Avenger': 26700,
#  'Avenger GTS': 73464,
#  'Avensis': 63493,
#  'Aventador': 69178,
#  'Aveo': 69114,
#  'Aveo G3': 1252861,
#  'Aviator': 70987,
#  'Avnte': 2347940,
#  'Axion': 1252966,
#  'Aygo': 2486966,
#  'Azera': 84807,
#  'Aztek': 62240,
#  'B-CROSS': 2347932,
#  'B15': 59284,
#  'B1600': 5958864,
#  'B18': 2109417,
#  'B18 CROSS': 5958943,
#  'B2000': 34711,
#  'B2200': 10994,
#  'B2500': 14029,
#  'B2600': 5958867,
#  'B2900': 2109310,
#  'B4000': 5958970,
#  'B9 Tribeca': 503685,
#  'BD': 2347919,
#  'BELAIR': 5958846,
#  'BJ': 2220981,
#  'BJ40': 2220984,
#  'BLS': 66683,
#  'BR-800': 2130510,
#  'BR-V': 3769991,
#  'Brisa': 2208285,
#  'BRZ': 1119443,
#  'BT-50': 2109309,
#  'BURBUJA LC80': 5958879,
#  'BX': 2109373,
#  'BX 1425': 3487201,
#  'Badao': 2400692,
#  'Baleno': 389398,
#  'Bandeirante': 389399,
#  'Barcheta': 1252990,
#  'Barchetta': 1252851,
#  'Barracuda': 67762,
#  'Beat': 103788,
#  'Beat urban': 2347907,
#  'Beauville': 2109386,
#  'Beetle': 60451,
#  'Belina': 389400,
#  'Benni': 2109381,
#  'Bentayga': 2318054,
#  'Beretta': 84787,
#  'Berlina': 2251647,
#  'Berlingo': 389401,
#  'Bertone': 68643,
#  'Besta': 389402,
#  'Besturn': 2400686,
#  'Bipper': 2109366,
#  'Black Wood': 503687,
#  'Blackwood': 71919,
#  'Blazer': 66422,
#  'Blitz': 112072,
#  'Bluebird': 527000,
#  'Boarding': 2400690,
#  'Bocanegra': 85022,
#  'Bolt EV': 1046562,
#  'Bonanza': 389403,
#  'Boneville': 503678,
#  'Bongo': 389404,
#  'Bonneville': 62540,
#  'Bora': 60677,
#  'Bora Sportwagen': 503688,
#  'Box': 580589,
#  'Boxer': 1252903,
#  'Boxer Furgon': 389405,
#  'Boxer Minibus': 1007097,
#  'Boxster': 60289,
#  'Boxter S ii': 2220962,
#  'Brasilia': 61067,
#  'Brasinca': 389406,
#  'Brava': 389407,
#  'Bravo': 41497,
#  'Break': 2251652,
#  'Breeze': 73009,
#  'Brera': 5244,
#  'Brio': 8799,
#  'Bronco': 67383,
#  'Buggy': 63592,
#  'Buggy Walk Sport': 1148989,
#  'Buick': 503671,
#  'Burbuja': 1252926,
#  'C-10': 2109387,
#  'C-15': 84789,
#  'C-1500': 2318074,
#  'C-20': 84791,
#  'C-25': 31299,
#  'C-35': 2130527,
#  'C-Crosser': 2486969,
#  'C-Elysée': 1252932,
#  'C-Max': 2486942,
#  'C1': 17875,
#  'C15': 14262,
#  'C2': 16258,
#  'C20': 16553,
#  'C206': 2400662,
#  'C3': 9003,
#  'C3 Aircross': 1252936,
#  'C3 Picasso': 389408,
#  'C30': 16563,
#  'C31': 31919,
#  'C32': 32623,
#  'C35': 2176998,
#  'C37': 2400679,
#  'C4': 12098,
#  'C4 Aircross': 1252931,
#  'C4 Cactus': 2109371,
#  'C4 Cactus X-Series': 11496023,
#  'C4 Grand Picasso': 1252934,
#  'C4 Lounge': 1252930,
#  'C4 Pallas': 389409,
#  'C4 Picasso': 389410,
#  'C4 Spacetourer': 4001225,
#  'C5': 49666,
#  'C5 Break': 389411,
#  'C5 Tourer': 389412,
#  'C52': 2109322,
#  'C6': 14543,
#  'C61': 2318117,
#  'C70': 31410,
#  'C8': 12295,
#  'C81': 31266,
#  'CA': 3228225,
#  'Camino': 5312938,
#  'CC': 61574,
#  'CEDRIC': 5958910,
#  'CEE D': 2486978,
#  'CERATO FORTE': 5958936,
#  'CERATO KOUP': 5958937,
#  'CERATO PRO': 5958935,
#  'CHANLING': 5958918,
#  'CHEVY C2': 5958845,
#  'CJ': 2109344,
#  'CJ-540': 2347904,
#  'CJ5': 62037,
#  'CJ6': 2347936,
#  'CJ7': 62898,
#  'CK': 2109413,
#  'CL': 3487202,
#  'CL-244': 1148991,
#  'CL-300': 1148986,
#  'CLASE D': 5958906,
#  'CLASE ML 230': 5958899,
#  'CLASE ML 250': 5958904,
#  'CLASE ML 270': 5958902,
#  'CLASE ML 320': 5958897,
#  'CLASE ML 350': 5958901,
#  'CLASE ML 430': 5958898,
#  'CLASE ML 500': 5958896,
#  'CLASE ML 55': 5958900,
#  'CLASE ML 550': 5958905,
#  'CLASE ML 63': 5958903,
#  'CLK': 503709,
#  'CLS': 2243263,
#  'Cobra': 65385,
#  'Comando': 244530,
#  'CONQUISTADOR': 5958840,
#  'COPEN': 5958930,
#  'Corcel': 2852522,
#  'CORD': 5958940,
#  'CORTINA': 16281,
#  'CORVAIR': 5958847,
#  'CR-V': 60561,
#  'CR-Z': 63934,
#  'CRESSIDE': 5958885,
#  'CRX': 389453,
#  'CS 15': 3769990,
#  'CS 35': 2109379,
#  'CT': 389454,
#  'CT200h': 2109314,
#  'CTS': 67675,
#  'CTS Coupe': 74097,
#  'CUPRA': 5958984,
#  'CV713': 6816706,
#  'CX': 10729,
#  'CX 20': 2109380,
#  'CX-3': 503696,
#  'CX-5': 66926,
#  'CX-7': 503699,
#  'CX-9': 503704,
#  'Cabina y Media': 3572353,
#  'Cabrio': 84840,
#  'Cabriolet': 64624,
#  'Cabstar': 62117,
#  'Caddy': 62158,
#  'Cadenza': 389413,
#  'Cala': 84818,
#  'Caldina': 2318130,
#  'Cale': 2347908,
#  'Caliber': 66709,
#  'Calibra': 84837,
#  'California': 72282,
#  'Camaro': 68313,
#  'Camaro Hot Wheels': 85184,
#  'Camaro ZLI': 84792,
#  'Camiones': 3228224,
#  'Camper': 111928,
#  'Campero': 2347959,
#  'Camry': 60388,
#  'Canter': 2109364,
#  'Canyon': 60755,
#  'Capella': 2347915,
#  'Capital': 1252973,
#  'Caprice': 68109,
#  'Captiva': 68141,
#  'Captiva Sport': 66667,
#  'Captur': 64614,
#  'Carajas': 1148990,
#  'Carat': 1252873,
#  'Caravan': 67558,
#  'Caravelle': 493855,
#  'Carens': 389415,
#  'Cargo': 389416,
#  'Cargo Box': 2400682,
#  'Cargo Van': 2109306,
#  'Caribe': 61081,
#  'Carina': 932427,
#  'Carnival': 389417,
#  'Carrera': 26574,
#  'Carry': 2109404,
#  'Catera': 68736,
#  'Cavalier': 66914,
#  'Cavalier Z24': 70878,
#  'Cayenne': 60439,
#  'Cayenne S': 93448,
#  'Cayenne Turbo': 2251651,
#  'Cayenne iii': 3487192,
#  'Cayman': 60430,
#  'Celebrity': 73322,
#  'Celer': 389418,
#  'Celerio': 2109402,
#  'Celica': 84858,
#  'Celta': 389419,
#  'Century': 73314,
#  'Cerato': 389420,
#  'Cerato 5': 2318131,
#  'Ceres': 2220965,
#  'Chairman': 2109323,
#  'Challenger': 70574,
#  'Challenger SRT8': 7352323,
#  'Changhe': 2400677,
#  'Changhe M100': 1007124,
#  'Charade': 389421,
#  'Charger': 68240,
#  'Charlotte': 2318095,
#  'Chasis': 1148996,
#  'Chassi': 389422,
#  'Cherokee': 61232,
#  'Cherokee Sport': 85042,
#  'Chery QQ': 389423,
#  'Chevelle': 7224015,
#  'Chevette': 84788,
#  'Chevy': 66675,
#  'Chevy 500': 389424,
#  'Chevy Nova': 84793,
#  'Chevy Pick Up': 503675,
#  'Chevy Van': 67774,
#  'Chevy equinox': 2347950,
#  'Cheyenne': 67557,
#  'Ciaz': 1119444,
#  'Cielo': 389425,
#  'Cimarron': 2109295,
#  'Cinquecento': 2220959,
#  'Cirrus': 66704,
#  'Citation': 2130523,
#  'City': 62015,
#  'Cityrover': 10365234,
#  'Civic': 32212,
#  'Civic Hybrid': 2486962,
#  'Clarus': 389426,
#  'Clase A': 503622,
#  'Clase B': 503630,
#  'Clase C': 503625,
#  'Clase CE': 2318096,
#  'Clase CL': 503627,
#  'Clase CLA': 503621,
#  'Clase CLC': 1252941,
#  'Clase CLK': 1252938,
#  'Clase CLS': 503631,
#  'Clase E': 503629,
#  'Clase G': 503624,
#  'Clase GL': 503633,
#  'Clase GLA': 1252939,
#  'Clase GLC': 1252940,
#  'Clase GLE': 1252987,
#  'Clase GLK': 503632,
#  'Clase GLS': 1252997,
#  'Clase M': 503628,
#  'Clase ML': 2220938,
#  'Clase R': 503634,
#  'Clase S': 71651,
#  'Clase SE': 2318097,
#  'Clase SEL': 2318098,
#  'Clase SL': 70390,
#  'Clase SLC': 1252988,
#  'Clase SLK': 503623,
#  'Clase SLR': 503626,
#  'Clase SLS': 1252993,
#  'Clase V': 1252943,
#  'Classe A': 389427,
#  'Classe B': 389428,
#  'Classe C': 389429,
#  'Classe C Touring': 389430,
#  'Classe CL': 389431,
#  'Classe CLC': 1119417,
#  'Classe CLK': 389433,
#  'Classe CLS': 389434,
#  'Classe Cla': 389432,
#  'Classe E': 389435,
#  'Classe E Touring': 389436,
#  'Classe GL': 389437,
#  'Classe GLA': 1119418,
#  'Classe GLC': 1119419,
#  'Classe GLE': 1119420,
#  'Classe GLK': 1119421,
#  'Classe GLS': 1148983,
#  'Classe ML': 389438,
#  'Classe R': 389439,
#  'Classe S': 389440,
#  'Classe SEC': 389441,
#  'Classe SL': 389442,
#  'Classe SLC': 1119422,
#  'Classe SLK': 389443,
#  'Classic': 6473,
#  'Clio': 60485,
#  'Clio Campus': 2486954,
#  'Clio Mío': 1252881,
#  'Clio Sedan': 389444,
#  'Club Wagon': 70026,
#  'Clubman': 389445,
#  'Clásico': 84866,
#  'Cnossus': 71705,
#  'Coaster': 1252921,
#  'Cobalt': 389446,
#  'Collbear': 2662823,
#  'Colorado': 66573,
#  'Colt': 389447,
#  'Comanche': 65997,
#  'Combi': 60610,
#  'Combo': 1252863,
#  'Commander': 60874,
#  'Compass': 16696,
#  'Concept S': 84819,
#  'Concorde': 69100,
#  'Continental': 67047,
#  'Continental GT': 74446,
#  'Contour': 66512,
#  'Cooper': 66416,
#  'Cooper Cabrio': 3304620,
#  'Cooper Clubman': 85057,
#  'Cooper Clubman S': 2130526,
#  'Cooper Countryman': 2220940,
#  'Cooper Coupé': 3304622,
#  'Cooper Roadster': 1119424,
#  'Cooper S': 1252978,
#  'Cooper S Cabrio': 3304621,
#  'Cooper S Coupé': 1119425,
#  'Cooper S Roadster': 1119426,
#  'Cordoba': 60266,
#  'Corolla': 60334,
#  'Corolla Cross': 11510704,
#  'Corolla Fielder': 1252927,
#  'Corona': 84857,
#  'Coronet': 67749,
#  'Corrado': 2347905,
#  'Corsa': 66609,
#  'Corsa Classic': 389448,
#  'Corsa Classic SW': 1252865,
#  'Corsa Combo': 2109388,
#  'Corsa II': 1252862,
#  'Corsa Pick-Up': 389449,
#  'Corsa Sedan': 389450,
#  'Corsa Wagon': 493858,
#  'Corsar': 64096,
#  'Corsica': 100564,
#  'Corvette': 44626,
#  'Cougar': 69305,
#  'Countryman': 70248,
#  'Coupe': 7507532,
#  'Coupe FX': 1046547,
#  'Coupê': 401950,
#  'Courier': 69528,
#  'Courier Van': 1007089,
#  'Cowin': 2109353,
#  'Cowry': 2347922,
#  'Crafter': 62180,
#  'Credos': 503657,
#  'Cressida': 2400697,
#  'Creta': 1007110,
#  'Croma': 2486944,
#  'Cronos': 228452,
#  'Cross Up': 389452,
#  'Cross Up!': 3304616,
#  'Crossfire': 68829,
#  'Crossfox': 61534,
#  'Crossgolf': 1119433,
#  'Crossover': 32740,
#  'Crosstour': 62025,
#  'Crown': 576584,
#  'Crown Victoria': 7302936,
#  'Cruze': 66905,
#  'Cruze 5': 2318132,
#  'Cruze II': 1252864,
#  'Cruze Sport': 493859,
#  'CS15': 7556080,
#  'CS75': 7556081,
#  'Cube': 416979,
#  'Cuore': 389455,
#  'Cutlass': 67707,
#  'D 100': 67986,
#  'D 150': 71772,
#  'D 250': 70671,
#  'D 350': 70723,
#  'D-10': 389456,
#  'D-20': 389457,
#  'D-21': 2318133,
#  'D-22': 2318134,
#  'D-40': 2109389,
#  'D-Max': 2109390,
#  'D100': 5280,
#  'D20': 45545,
#  'D21': 389458,
#  'D22': 1252957,
#  'D5 Torer': 389459,
#  'D60': 6753,
#  'DB11': 1046546,
#  'DB7': 1252994,
#  'DB9': 71223,
#  'DBS': 69161,
#  'Demon': 3944679,
#  'DMAX': 2347952,
#  'DS3': 389463,
#  'DS4': 389464,
#  'DS5': 389465,
#  'DS7': 3572358,
#  'DTS': 84786,
#  'DUNNA': 5958922,
#  'DX 3': 5958835,
#  'DX 7': 5958836,
#  'Daily': 1148987,
#  'Daimler': 1046549,
#  'Dakar': 266927,
#  'Dakota': 66771,
#  'Damas': 1252909,
#  'Damas Coach': 2220948,
#  'Dart': 14748,
#  'Datsun': 64076,
#  'Daytona': 26727,
#  'Dedra': 2251649,
#  'Deer': 2109401,
#  'Defender': 71835,
#  'Del Rey': 389460,
#  'Delica': 2318135,
#  'Delta': 2011,
#  'Demio': 2318118,
#  'Derby': 62739,
#  'Deville': 66877,
#  'Diablo': 84817,
#  'Diamante': 903129,
#  'Discovery': 67077,
#  'Discovery 3': 1007091,
#  'Discovery 4': 1007092,
#  'Discovery sport': 1007093,
#  'Diva': 273414,
#  'Dmax E5': 2318137,
#  'Doble Cabina': 61084,
#  'Doblo': 389461,
#  'Doblo Cargo': 389462,
#  'DS7 Crossback': 7556082,
#  'Ducato': 76499,
#  'Dumper': 2400673,
#  'Duna': 389466,
#  'Duna Weekend': 2130517,
#  'Durango': 66817,
#  'Duster': 64855,
#  'Duster Oroch': 389467,
#  'Duty Truck': 3228237,
#  'Dzire': 3228241,
#  'E-150': 84797,
#  'E-350': 84799,
#  'E-Pace': 3228220,
#  'E-Type': 7248581,
#  'E1600': 1252911,
#  'E2200': 50926,
#  'E5': 8797,
#  'EC7': 860,
#  'EC7 Sedan': 2318083,
#  'EC7 Sport': 2318084,
#  'Elite': 33952,
#  'ES': 72428,
#  'ESPIRIT': 5958825,
#  'ETERNE': 5958826,
#  'ETOILE': 5958854,
#  'Everest': 191461,
#  'Evora': 928608,
#  'EX37': 2318139,
#  'Echo': 84856,
#  'Eclipse': 67281,
#  'Eclipse Cross': 7128937,
#  'Econo': 2220942,
#  'Econoline': 503666,
#  'Ecosport': 389468,
#  'Ecosport kd': 2130521,
#  'Edge': 69693,
#  'El Dorado': 7354359,
#  'Elan': 1007125,
#  'Elantra': 61443,
#  'Elba': 389469,
#  'Eldorado': 505330,
#  'Element': 49826,
#  'Elise': 69272,
#  'Elise 250 Special Edition': 503648,
#  'Elise Cup 250': 503646,
#  'Elise Race 250': 503647,
#  'Elise Sport': 503644,
#  'Elise Sport 220': 503645,
#  'Emgrand': 1252901,
#  'Emgrand 7': 2820706,
#  'Emgrand 718': 2109410,
#  'Emgrand EC7': 2347918,
#  'Emgrand GS': 2662822,
#  'Emgrand X7 Sport': 2820707,
#  'Emgrand ex7': 2109411,
#  'Enclave': 67946,
#  'Encore': 73483,
#  'Endeavor': 68529,
#  'Engesa': 1119427,
#  'Engesa 1': 389470,
#  'Engesa 4': 389471,
#  'Envision': 73939,
#  'Envoy': 123195,
#  'Enzo': 70704,
#  'Eon': 2109360,
#  'Eos': 63746,
#  'Epica': 69368,
#  'Equinox': 66640,
#  'Equus': 64044,
#  'Ertiga': 2109403,
#  'Escalade': 68144,
#  'Escalade ESV': 66752,
#  'Escalade EXT': 66795,
#  'Escape': 68586,
#  'Escarabajo': 1252869,
#  'Escort': 67158,
#  'Espace': 2220949,
#  'Espada': 73932,
#  'Espero': 389472,
#  'Esprit': 1007126,
#  'Essentia': 2318099,
#  'Estaquitas': 61170,
#  'Esteem': 123230,
#  'Estoque': 7349429,
#  'Etios': 389473,
#  'Etios Cross': 1007094,
#  'Etios Sedán': 3304617,
#  'Eulove': 2662818,
#  'Euro Clio': 1252989,
#  'Euroscort': 2318089,
#  'Eurovan': 62727,
#  'Evasion': 389474,
#  'Evolution': 916105,
#  'Evoque': 64491,
#  'Evora 400': 503653,
#  'Evora Sport 410': 503654,
#  'Excel': 389475,
#  'Excursion': 70696,
#  'Exeo': 64019,
#  'Exige': 503643,
#  'Exige 350 Special Edition': 503652,
#  'Exige Sport 350': 503649,
#  'Exige Sport 380': 503651,
#  'Exige V6 Cup R': 503650,
#  'Expedition': 44684,
#  'Expert': 42934,
#  'Explorer': 8859,
#  'Explorer Sport Trac': 68238,
#  'Expo': 84835,
#  'Expo Wagon': 2220961,
#  'Express': 11447,
#  'Express Van': 66642,
#  'F 355': 2347934,
#  'F 360': 2347933,
#  'F 430': 2347935,
#  'F-100': 389476,
#  'F-1000': 389477,
#  'F-150': 93447,
#  'F-200': 93402,
#  'F-250': 76866,
#  'F-308': 1252982,
#  'F-350': 76864,
#  'F-355': 1252979,
#  'F-400': 1245760,
#  'F-430': 1252985,
#  'F-450': 76702,
#  'F-456': 1252981,
#  'F-550': 76703,
#  'F-599': 1252983,
#  'F-600': 503663,
#  'F-612': 1252984,
#  'F-750': 5958955,
#  ...}

# %%
# extrair_ano_inicial_ano_final('VOLKSWAGEN SANTANA GLI AP 2000 2.0 L 8V SOHC L4 Ano: 1994 até: 1996')
# Out:
# ('1994', '1996')

# %%
from tqdm.notebook import tqdm


# associacoes = []
#
# for modelo_raw in tqdm(modelos_raw):
#     data = {'Descrição': modelo_raw, "Marca": None, "Marca Id": None, "Modelo": None, "Modelo Id": None, "Ano inicial": None, "Ano final": None}
#     for nome_marca, marca_id in marcas.items():
#         if nome_contem_string(modelo_raw, nome_marca):
#             data["Marca"] = nome_marca
#             data["Marca Id"] = marca_id
#             break
#     marca = data["Marca"]
#     for nome_modelo, modelo_id in modelos.items():
#         if nome_contem_string(modelo_raw, f"{marca} {nome_modelo}"):
#             data["Modelo"] = nome_modelo
#             data["Modelo Id"] = modelo_id
#             break
#     data["Ano inicial"], data["Ano final"] = extrair_ano_inicial_ano_final(modelo_raw)
#     associacoes.append(data)

def associe(modelo_raw):
    data = {'Descrição': modelo_raw, "Marca": None, "Marca Id": None, "Modelo": None, "Modelo Id": None,
            "Ano inicial": None, "Ano final": None}
    for nome_marca, marca_id in marcas.items():
        if nome_contem_string(modelo_raw, nome_marca):
            data["Marca"] = nome_marca
            data["Marca Id"] = marca_id
            break
    marca = data["Marca"]
    for nome_modelo, modelo_id in modelos.items():
        if nome_contem_string(modelo_raw, f"{marca} {nome_modelo}"):
            data["Modelo"] = nome_modelo
            data["Modelo Id"] = modelo_id
            break
    data["Ano inicial"], data["Ano final"] = extrair_ano_inicial_ano_final(modelo_raw)
    return data

# pd.DataFrame(associacoes).to_excel('associacoes.xlsx')

# %%
candidatos_marca = defaultdict(set)
associacoes = []

descricoes_raw_set = set(descricoes_raw)

for marca in tqdm(marcas):
    for descricao_raw in descricoes_raw_set:
        if descricao_raw.startswith(marca.upper()):
            candidatos_marca[marca].add(descricao_raw)
    descricoes_raw_set = descricoes_raw_set - candidatos_marca[marca]

descricoes_sem_associacao = descricoes_raw_set
# Out:
#   0%|          | 0/198 [00:00<?, ?it/s]

# %%
with open("descricoes_sem_associacao.txt", "w", encoding="utf-8") as f:
    for line in descricoes_sem_associacao:
        f.write(f"\n{descricao_raw}")

len(descricoes_sem_associacao)
# Out:
# 14476

# %%
marca_modelo = {}


def determinar_modelo(data, marca, descricao, modelos_associados):
    for nome_modelo, modelo_id in modelos.items():
        if nome_modelo in modelos_associados and marca_modelo[nome_modelo] != marca:
            continue
        if nome_contem_string(descricao, f"{marca} {nome_modelo}"):
            marca_modelo[nome_modelo] = marca
            data["Modelo"] = nome_modelo
            data["Modelo Id"] = modelo_id
            break

    return data


def associcao_melhorado(candidatos_marca_dict):
    associacoes = []
    for marca, candidatos in tqdm(candidatos_marca_dict.items(), total=len(candidatos_marca_dict)):
        for candidado in candidatos:
            if nome_contem_string(candidado, marca):
                data = {'Descrição': candidado, "Marca": marca, "Marca Id": marcas[marca], "Modelo": None,
                        "Modelo Id": None,
                        "Ano inicial": None, "Ano final": None}
                data = determinar_modelo(data, marca, candidado, marca_modelo)
                data["Ano inicial"], data["Ano final"] = extrair_ano_inicial_ano_final(candidado)
                associacoes.append(data)

    return associacoes


associacoes = associcao_melhorado(candidatos_marca)
pd.DataFrame(associacoes).to_excel('associacoes.xlsx')
# Out:
#   0%|          | 0/198 [00:00<?, ?it/s]

# %%
# from multiprocessing import Pool
#
# with Pool() as pool:
#     associacoes = [a for a in tqdm(pool.map(associe, descricoes_raw), total=descricoes_raw)]
#
# pd.DataFrame(associacoes).to_excel('associacoes.xlsx')
